# %% [markdown]
# **Installing pandas**

# %%
# !pip install pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.4'

# %% [markdown]
# Working with pandas for housing datas

# %%
housingData = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")

# %%
print(housingData.head(15))
housingData["median_house_value"].max()
# Out:
#     longitude  latitude  ...  median_income  median_house_value
# 0     -114.31     34.19  ...         1.4936             66900.0
# 1     -114.47     34.40  ...         1.8200             80100.0
# 2     -114.56     33.69  ...         1.6509             85700.0
# 3     -114.57     33.64  ...         3.1917             73400.0
# 4     -114.57     33.57  ...         1.9250             65500.0
# 5     -114.58     33.63  ...         3.3438             74000.0
# 6     -114.58     33.61  ...         2.6768             82400.0
# 7     -114.59     34.83  ...         1.7083             48500.0
# 8     -114.59     33.61  ...         2.1782             58400.0
# 9     -114.60     34.83  ...         2.1908             48100.0
# 10    -114.60     33.62  ...         2.6797             86500.0
# 11    -114.60     33.60  ...         1.6250             62000.0
# 12    -114.61     34.84  ...         2.1571             48600.0
# 13    -114.61     34.83  ...         3.2120             70400.0
# ...

# %%
housingData.describe()
# Out:
#           longitude      latitude  ...  median_income  median_house_value
# count  17000.000000  17000.000000  ...   17000.000000        17000.000000
# mean    -119.562108     35.625225  ...       3.883578       207300.912353
# std        2.005166      2.137340  ...       1.908157       115983.764387
# min     -124.350000     32.540000  ...       0.499900        14999.000000
# 25%     -121.790000     33.930000  ...       2.566375       119400.000000
# 50%     -118.490000     34.250000  ...       3.544600       180400.000000
# 75%     -118.000000     37.720000  ...       4.767000       265000.000000
# max     -114.310000     41.950000  ...      15.000100       500001.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# Pictorial Recreations of Data

# %%
housingData.hist("housing_median_age")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7941c22630>]],
#       dtype=object)

# %%
housingData.hist("median_income")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7939d9c5c0>]],
#       dtype=object)

# %%
housingData.hist("population")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7939d93e80>]],
#       dtype=object)

# %%
housingData.hist("median_income")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7939d87f28>]],
#       dtype=object)

# %%
df=pd.DataFrame(
    {
        "Name" : ["Ravi","Raju","Aravind","Ajith"],
        "Age" : [15,18,20,23]
    }
)

# %%
df
# Out:
#       Name  Age
# 0     Ravi   15
# 1     Raju   18
# 2  Aravind   20
# 3    Ajith   23

# %%
housingData.iloc[0:10,3:]
# Out:
#    total_rooms  total_bedrooms  ...  median_income  median_house_value
# 0       5612.0          1283.0  ...         1.4936             66900.0
# 1       7650.0          1901.0  ...         1.8200             80100.0
# 2        720.0           174.0  ...         1.6509             85700.0
# 3       1501.0           337.0  ...         3.1917             73400.0
# 4       1454.0           326.0  ...         1.9250             65500.0
# 5       1387.0           236.0  ...         3.3438             74000.0
# 6       2907.0           680.0  ...         2.6768             82400.0
# 7        812.0           168.0  ...         1.7083             48500.0
# 8       4789.0          1175.0  ...         2.1782             58400.0
# 9       1497.0           309.0  ...         2.1908             48100.0
#
# [10 rows x 6 columns]

# %%
housingData.plot.scatter(x="median_income",y="population")

# %%
df=pd.DataFrame(
  {
    "Experience":[x for x in range(0,20,2)],
    "Age" : [y for y in range(22,42,2)]
  }
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Experience  10 non-null     int64
#  1   Age         10 non-null     int64
# dtypes: int64(2)
# memory usage: 288.0 bytes

# %%
df.describe()
# Out:
#        Experience        Age
# count   10.000000  10.000000
# mean     9.000000  31.000000
# std      6.055301   6.055301
# min      0.000000  22.000000
# 25%      4.500000  26.500000
# 50%      9.000000  31.000000
# 75%     13.500000  35.500000
# max     18.000000  40.000000

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

sns.lineplot(x="Age",y="Experience",data=df)
