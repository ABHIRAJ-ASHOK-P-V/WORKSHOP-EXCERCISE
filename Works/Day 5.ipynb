# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ae45923b-1d65-41d2-ac67-3dcd284d9020" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae45923b-1d65-41d2-ac67-3dcd284d9020">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance (3).csv
# User uploaded file "StudentsPerformance.csv" with length 72036 bytes

# %%
# !ls
# Out:
#  sample_data		       'StudentsPerformance (3).csv'
# 'StudentsPerformance (1).csv'   StudentsPerformance.csv
# 'StudentsPerformance (2).csv'

# %%
import pandas as pd

# %%
students = pd.read_csv("StudentsPerformance.csv")
students.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
students.plot.scatter("math score", "gender", figsize=(10,5))

# %% [markdown]
# From the plot we are able to identify that Female students are there with all the maths score. that means the female candidatea are having more number than the male constitunecy

# %%
std = students[students["reading score"]<40]

# %%
std.head()
# Out:
#     gender race/ethnicity  ... reading score writing score
# 17  female        group B  ...            32            28
# 59  female        group C  ...            17            10
# 61    male        group A  ...            39            34
# 66    male        group D  ...            37            37
# 76    male        group E  ...            26            22
#
# [5 rows x 8 columns]

# %%
import seaborn as sns
sns.countplot(std['parental level of education'], orient = 'h')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# it can be infered that some high school parents are showing majority compared to the rest of the parents. the expectancy of child being well scoring also depend on the education of the parents to an extend

# %%
students.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# TItanic Data Uploaded

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-df81c3fb-7104-47b6-a60b-c3fdff58db69" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-df81c3fb-7104-47b6-a60b-c3fdff58db69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train_and_test2.csv to train_and_test2.csv
# User uploaded file "train_and_test2.csv" with length 83879 bytes

# %%
import pandas as pd

# %%
train = pd.read_csv("train_and_test2.csv")
train.head()
# Out:
#    Passengerid   Age     Fare  Sex  ...  Embarked  zero.17  zero.18  2urvived
# 0            1  22.0   7.2500    0  ...       2.0        0        0         0
# 1            2  38.0  71.2833    1  ...       0.0        0        0         1
# 2            3  26.0   7.9250    1  ...       2.0        0        0         1
# 3            4  35.0  53.1000    1  ...       2.0        0        0         1
# 4            5  35.0   8.0500    0  ...       2.0        0        0         0
#
# [5 rows x 28 columns]

# %%
train.describe()
# Out:
#        Passengerid          Age         Fare  ...  zero.17  zero.18     2urvived
# count  1309.000000  1309.000000  1309.000000  ...   1309.0   1309.0  1309.000000
# mean    655.000000    29.503186    33.281086  ...      0.0      0.0     0.261268
# std     378.020061    12.905241    51.741500  ...      0.0      0.0     0.439494
# min       1.000000     0.170000     0.000000  ...      0.0      0.0     0.000000
# 25%     328.000000    22.000000     7.895800  ...      0.0      0.0     0.000000
# 50%     655.000000    28.000000    14.454200  ...      0.0      0.0     0.000000
# 75%     982.000000    35.000000    31.275000  ...      0.0      0.0     1.000000
# max    1309.000000    80.000000   512.329200  ...      0.0      0.0     1.000000
#
# [8 rows x 28 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 28 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Passengerid  1309 non-null   int64
#  1   Age          1309 non-null   float64
#  2   Fare         1309 non-null   float64
#  3   Sex          1309 non-null   int64
#  4   sibsp        1309 non-null   int64
#  5   zero         1309 non-null   int64
#  6   zero.1       1309 non-null   int64
#  7   zero.2       1309 non-null   int64
#  8   zero.3       1309 non-null   int64
#  9   zero.4       1309 non-null   int64
#  10  zero.5       1309 non-null   int64
#  11  zero.6       1309 non-null   int64
#  12  Parch        1309 non-null   int64
#  13  zero.7       1309 non-null   int64
#  14  zero.8       1309 non-null   int64
#  15  zero.9       1309 non-null   int64
#  16  zero.10      1309 non-null   int64
#  17  zero.11      1309 non-null   int64
#  18  zero.12      1309 non-null   int64
# ...

# %%
train.plot.scatter("Age","2urvived",figsize=(10,5))
